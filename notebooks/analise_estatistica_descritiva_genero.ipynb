# %% [markdown]
# # 📊 Estatística Descritiva
#
# Este notebook realiza a análise descritiva das seguintes variáveis:
#
# - Gênero (Qualitativa nominal)
# - Altura (Quantitativa contínua)
# - Peso (Quantitativa contínua)
# - Opinião sobre degradação ambiental (Qualitativa ordinal)
# - Opinião sobre regulação de fake news (Qualitativa ordinal)
# - Número de redes sociais (Quantitativa discreta)

# %%
import pandas as pd

# Carregar a planilha
df = pd.read_excel('../datasets/2026ABC121dados.xlsx')

# Mostrar as primeiras linhas
df.head()
# Out:
#    Ident   Ano Turma  Idade  Altura  Peso  Irmãos     Gênero  \
# 0      1  2025     N     45     175  89.0       0  Masculino
# 1      2  2025     N     49     172  63.0       0  Masculino
# 2      3  2025     N     40     178  99.7       0  Masculino
# 3      4  2025     D     19     186  70.0       0  Masculino
# 4      5  2025     D     18     180  96.0       1  Masculino
#
#   Uso_dados_pessoais                                     Big_tech_ética  \
# 0                Não  Pouca importância: A ética é negligenciada, ex...
# 1     Não sei/Talvez  Importância moderada: Há algum esforço, mas a ...
# 2                Sim  Pouca importância: A ética é negligenciada, ex...
# 3                Sim  Nenhuma importância: As big-techs ignoram comp...
# 4                Não  Pouca importância: A ética é negligenciada, ex...
#
#    Num_redes_sociais Regulação_fake_news                Mudanças_climáticas  \
# 0                  4                 Sim          Estou muito preocupado(a)
# ...

# %% [markdown]
# ## 📌 Estatística Descritiva Geral

# %%
# Estatísticas gerais
df.describe(include='all')
# Out:
#              Ident          Ano Turma       Idade      Altura        Peso  \
# count   195.000000   195.000000   195  195.000000  195.000000  195.000000
# unique         NaN          NaN     2         NaN         NaN         NaN
# top            NaN          NaN     N         NaN         NaN         NaN
# freq           NaN          NaN   144         NaN         NaN         NaN
# mean     98.000000  2025.394872   NaN   23.523077  173.610256   72.267692
# std      56.435804     0.490081   NaN    7.633569    8.417085   15.456992
# min       1.000000  2025.000000   NaN   17.000000  150.000000   37.000000
# 25%      49.500000  2025.000000   NaN   19.000000  169.500000   60.000000
# 50%      98.000000  2025.000000   NaN   21.000000  174.000000   70.000000
# 75%     146.500000  2026.000000   NaN   25.000000  180.000000   82.000000
# max     195.000000  2026.000000   NaN   61.000000  196.000000  120.000000
#
#             Irmãos     Gênero Uso_dados_pessoais  \
# ...

# %% [markdown]
# ## 👤 Gênero (Qualitativa Nominal)

# %%
df['Gênero'].value_counts()
# Out:
# Gênero
# Masculino            154
# Feminino              31
# Outro                  5
# Prefiro não dizer      5
# Name: count, dtype: int64

# %% [markdown]
# ## 📏 Altura (Quantitativa Contínua)

# %%
df['Altura'].describe()
# Out:
# count    195.000000
# mean     173.610256
# std        8.417085
# min      150.000000
# 25%      169.500000
# 50%      174.000000
# 75%      180.000000
# max      196.000000
# Name: Altura, dtype: float64

# %% [markdown]
# ## ⚖️ Peso (Quantitativa Contínua)

# %%
df['Peso'].describe()
# Out:
# count    195.000000
# mean      72.267692
# std       15.456992
# min       37.000000
# 25%       60.000000
# 50%       70.000000
# 75%       82.000000
# max      120.000000
# Name: Peso, dtype: float64

# %% [markdown]
# ## 🌱 Opinião sobre degradação ambiental (Qualitativa Ordinal)

# %%
df['Degradação_meio_ambiente'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\leand\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Opinião sobre degradação ambiental'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## 📰 Opinião sobre regulação de fake news (Qualitativa Ordinal)

# %%
df['Opinião sobre regulação de fake news'].value_counts()

# %% [markdown]
# ## 📱 Número de redes sociais (Quantitativa Discreta)

# %%
df['Número de redes sociais'].describe()
